# %% [markdown]
# ## License Plate Detection
#
# Source of Dataset: [license-plate-detection](https://github.com/RobertLucian/license-plate-dataset)
#
# Source of Learning Transfer Learning on YoloV3: [YoloV3-spp](https://github.com/ultralytics/yolov3/wiki/Train-Custom-Data)

# %%
import time
import torch
import glob
import os

from IPython.display import Image, clear_output

# %% [markdown]
# ### Training the Model

# %%
# !python3 train.py --cfg model.cfg --data data/model.data --epochs 350 --weights weights/last.pt

# %%
# !python3 -c "from utils import utils; utils.plot_results()"  # plot training results
Image(filename='results.png', width=800)

# %% [markdown]
# ### Save Weights for TensorFlow
#
# [Reference](https://github.com/ultralytics/yolov3#darknet-conversion)

# %%
# !python3  -c "from models import *; convert('cfg/model.cfg', 'weights/best.pt')"
# Out:
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Success: converted 'weights/best.pt' to 'weights/best.weights'
